# %%
import pandas as pd

# %%
aircon=pd.read_csv('에어컨협력사DATA(AGENT).csv')
# Out:
# C:\Users\wonnho\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (17,19,22,23,25,26,27,28,29,31,32,33,34,35,37,38,39,40,41,43,44,45,46,47,49,50,51,52,53,55,56,57,58,59,61,62,63,64,65,67,68,69,70,71,73,74,75,76,77,79,80,81,82,83,85,86,87,88,89,91,92,93,94,95,97,98,99,100,101,103,104,105) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
aircon.head()
# Out:
#     SEC_CD       INSP_TIME      PART_CD  INS_PER HQ_CD VENDOR_SEQ  \
# 0  SEC_OQC  20210419145444  DB90-12086C      NaN  DDJV       DDJV
# 1  SEC_OQC  20210419145446  DB90-12086C      NaN  DDJV       DDJV
# 2  SEC_OQC  20210419145448  DB90-12086C      NaN  DDJV       DDJV
# 3  SEC_OQC  20210419145517  DB90-12086C      NaN  DDJV       DDJV
# 4  SEC_OQC  20210419145521  DB90-12086C      NaN  DDJV       DDJV
#
#     MODEL_CODE MODEL_NAME              SERIAL_CODE                  QR_CODE  \
# 0  DB90-12086C      RODIN  B0DB9012086CDDJVR4K0245  B0DB9012086CDDJVR4K0245
# 1  DB90-12086C      RODIN  B0DB9012086CDDJVR4K0246  B0DB9012086CDDJVR4K0246
# 2  DB90-12086C      RODIN  B0DB9012086CDDJVR4K0247  B0DB9012086CDDJVR4K0247
# 3  DB90-12086C      RODIN  B0DB9012086CDDJVR4K0248  B0DB9012086CDDJVR4K0248
# 4  DB90-12086C      RODIN  B0DB9012086CDDJVR4K0250  B0DB9012086CDDJVR4K0250
#
#    ...  NO892 NO893  NO894  NO895  NO896 NO897 NO898 NO899  NO900  \
# ...

# %%
aircon['NO7'].unique()
# Out:
# array(['PASS', nan, 'Z7287', 'Z7285', 'Z8642', 'FAIL', 'Z7282', 'Z7947',
#        'Z7817', 'Z7286', 'A0355', 'Z7841', 'Z9071', 'Z9073', 'Z7283',
#        'Z7945', 'Z8649', 'Z8648'], dtype=object)

# %%
aircon['NO7'].[150:211]
# Out:
#   File "C:\Users\wonnho\AppData\Local\Temp/ipykernel_9624/1684343521.py", line 1
#     aircon['NO7'].[150:211]
#                   ^
# SyntaxError: invalid syntax

# %%
aircon[aircon['NO']=='FAIL'][0:16]
# Out:
#        SEC_CD       INSP_TIME      PART_CD  INS_PER HQ_CD VENDOR_SEQ  \
# 2254  SEC_OQC  20210421153523  DB90-12084A      NaN  DDJV       DDJV
# 2259  SEC_OQC  20210421153621  DB90-12084A      NaN  DDJV       DDJV
# 2274  SEC_OQC  20210421154011  DB90-12084A      NaN  DDJV       DDJV
# 2275  SEC_OQC  20210421155301  DB90-12084A      NaN  DDJV       DDJV
# 2279  SEC_OQC  20210421153630  DB90-12084A      NaN  DDJV       DDJV
# 2299  SEC_OQC  20210421153754  DB90-12084A      NaN  DDJV       DDJV
# 2402  SEC_OQC  20210421163813  DB90-12084A      NaN  DDJV       DDJV
# 2424  SEC_OQC  20210421164103  DB90-12084A      NaN  DDJV       DDJV
# 2576  SEC_OQC  20210421165159  DB90-12084A      NaN  DDJV       DDJV
# 2591  SEC_OQC  20210421164720  DB90-12084A      NaN  DDJV       DDJV
# 2592  SEC_OQC  20210421164827  DB90-12084A      NaN  DDJV       DDJV
# 2595  SEC_OQC  20210421165021  DB90-12084A      NaN  DDJV       DDJV
# 2606  SEC_OQC  20210421170527  DB90-12084A      NaN  DDJV       DDJV
# ...

# %%
aircon.columns[0:80]
# Out:
# Index(['SEC_CD', 'INSP_TIME', 'PART_CD', 'INS_PER', 'HQ_CD', 'VENDOR_SEQ',
#        'MODEL_CODE', 'MODEL_NAME', 'SERIAL_CODE', 'QR_CODE', 'VEN_ECN_NO',
#        'REWORK', 'JIG_CD', 'VED_LOT_NO', 'INSP_NO', 'NO1', 'NO2', 'NO3', 'NO4',
#        'NO5', 'NO6', 'NO7', 'NO8', 'NO9', 'NO10', 'NO11', 'NO12', 'NO13',
#        'NO14', 'NO15', 'NO16', 'NO17', 'NO18', 'NO19', 'NO20', 'NO21', 'NO22',
#        'NO23', 'NO24', 'NO25', 'NO26', 'NO27', 'NO28', 'NO29', 'NO30', 'NO31',
#        'NO32', 'NO33', 'NO34', 'NO35', 'NO36', 'NO37', 'NO38', 'NO39', 'NO40',
#        'NO41', 'NO42', 'NO43', 'NO44', 'NO45', 'NO46', 'NO47', 'NO48', 'NO49',
#        'NO50', 'NO51', 'NO52', 'NO53', 'NO54', 'NO55', 'NO56', 'NO57', 'NO58',
#        'NO59', 'NO60', 'NO61', 'NO62', 'NO63', 'NO64', 'NO65'],
#       dtype='object')

# %%
aircon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 669454 entries, 0 to 669453
# Columns: 916 entries, SEC_CD to FILE_NAME
# dtypes: float64(829), int64(1), object(86)
# memory usage: 4.6+ GB

# %%
aircon.describe(include='all')
# Out:
#          SEC_CD     INSP_TIME      PART_CD  INS_PER   HQ_CD VENDOR_SEQ  \
# count    669454  6.694540e+05       669454      0.0  669454     669454
# unique        1           NaN          127      NaN       2          2
# top     SEC_OQC           NaN  DB90-12084N      NaN    DDJV       DDJV
# freq     669454           NaN        39417      NaN  392283     392283
# mean        NaN  2.021059e+13          NaN      NaN     NaN        NaN
# std         NaN  1.313116e+08          NaN      NaN     NaN        NaN
# min         NaN  2.021040e+13          NaN      NaN     NaN        NaN
# 25%         NaN  2.021051e+13          NaN      NaN     NaN        NaN
# 50%         NaN  2.021060e+13          NaN      NaN     NaN        NaN
# 75%         NaN  2.021062e+13          NaN      NaN     NaN        NaN
# max         NaN  2.021120e+13          NaN      NaN     NaN        NaN
#
#          MODEL_CODE     MODEL_NAME              SERIAL_CODE  \
# ...

# %%
inspection=pd.read_csv('검사항목코드.csv')

# %%
inspection.head(11)
# Out:
#    PARA_CD                          PARA_NM
# 0    02918                          Length1
# 1    05537                        Aparencia
# 2    15607                           width1
# 3    21768                           HEIGHT
# 4    A0099                 output voltage 1
# 5    A0100               sedimentation test
# 6    A0101  carburized hardening layer test
# 7    A0102                            clear
# 8    A0103             penetration strength
# 9    A0104                     current test
# 10   A0105           film adhesiveness(VCM)

# %%
inspection.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2395 entries, 0 to 2394
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   PARA_CD  2395 non-null   object
#  1   PARA_NM  2366 non-null   object
# dtypes: object(2)
# memory usage: 37.5+ KB

# %%
defective=pd.read_csv('시장불량세트SN.csv')

# %%
defective.head(11)
# Out:
#           MARKET_SN
# 0   BB74P3ER500221V
# 1   BB6HP3ER600111P
# 2   BBA3P3ER700033Z
# 3   BB74P3ER900075M
# 4   BBBMP3ER800139K
# 5   BKMPP3ER506254V
# 6   BK7EP3ER500564M
# 7   BBBMP3ER700137A
# 8   BB6HP3ER700473Y
# 9   BD4CP3ER600073W
# 10  BKPDP3ER500167K

# %%
B0DB9012084BDDJVR4M0184

# %%
defective.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MARKET_SN  66 non-null     object
# dtypes: object(1)
# memory usage: 656.0+ bytes

# %%
history=pd.read_csv('조립이력(KEY).csv')

# %%
history.head()
# Out:
#    WORK_YMD         ASSY_DT    MODEL_CODE    PRODC_MAGT_NO VEND_CODE  \
# 0  20210105  20210105112017  AF17TX773TZN  BDRDP3ER100034F      DDJV
# 1  20210105  20210105111743  AF17TX773TZN  BDRDP3ER100029A      DDJV
# 2  20210105  20210105111734  AF17TX773TZN  BDRDP3ER100032Z      DDJV
# 3  20210105  20210105112637  AF17TX773TZN  BDRDP3ER100041P      DDJV
# 4  20210105  20210105111819  AF17TX773TZN  BDRDP3ER100031L      DDJV
#
#      MATR_CODE                  ASSY_NO
# 0  DB90-11536C  E2DB9011536CDDJVR140045
# 1  DB90-11536C  E2DB9011536CDDJVR140072
# 2  DB90-11536C  E2DB9011536CDDJVR140075
# 3  DB90-11536C  E2DB9011536CDDJVR140078
# 4  DB90-11536C  E2DB9011536CDDJVR140090

# %%
history['MODEL_CODE'].unique()
# Out:
# array(['AF17TX773TZN', 'AF19TX771BFN', 'AF25AX975VAN', 'AF23AX977VFN',
#        'AF23AX977CFN', 'AF25AX977CFN', 'AF17AX771VFN', 'AF19AX772BFN',
#        'AF19AX773BZN', 'AF17AX772BFN', 'AF17AX773BZN', 'AF17AX772LFN',
#        'AF17AX773VZN', 'AF19AX773VZN', 'AF17AX978CZN', 'AF17TX773BZN',
#        'AF19AX771VFN', 'AF19AX772LFN', 'AF17TX772TFN', 'AF17TX771BFN',
#        'AF25TX978MZN', 'AF20AX978CZN', 'AF20AX978VZN', 'AF25AX975CAN',
#        'AF19AX773EZN', 'AF17AX773EZN', 'AF17TX772BFN', 'AF19A7974GSN',
#        'AF19A7974BSN', 'AF17A7974BSN', 'AF17A7974GSN', 'AF17A7974EZN',
#        'AF17A7974ESN', 'AF17A7974TZN', 'AF17A7974GZN', 'AF19A7974GZN',
#        'AF17A7974BZN', 'AF19A7974ESN', 'AF19A7974BZN', 'AF17AX773FZN',
#        'AF19AX773FZN', 'AF17AX773YZN', 'AF19AX773YZN', 'AF20AX978FZN',
#        'AF20AX978YZN', 'AF19A7974EZN', 'AF17A7974FZN', 'AF19A7974FZN',
#        'AF19A7974YZN', 'AF17A7974NZN', 'AF19A7974NZN', 'AF17A7974NSN',
# ...

# %%
history.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299826 entries, 0 to 299825
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   WORK_YMD       299826 non-null  int64
#  1   ASSY_DT        299826 non-null  int64
#  2   MODEL_CODE     299826 non-null  object
#  3   PRODC_MAGT_NO  299826 non-null  object
#  4   VEND_CODE      299826 non-null  object
#  5   MATR_CODE      299826 non-null  object
#  6   ASSY_NO        299826 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 16.0+ MB

# %%
aircon[aircon['SERIAL_CODE'] == 'B0DB9012085EDDJVR630198']
# Out:
#          SEC_CD       INSP_TIME      PART_CD  INS_PER HQ_CD VENDOR_SEQ  \
# 382185  SEC_OQC  20210603132308  DB90-12085E      NaN  DDJV       DDJV
# 382217  SEC_OQC  20210603133637  DB90-12085E      NaN  DDJV       DDJV
# 382326  SEC_OQC  20210603132308  DB90-12085E      NaN  DDJV       DDJV
#
#          MODEL_CODE       MODEL_NAME              SERIAL_CODE  \
# 382185  DB90-12085E  MEMORY2(21Y)85E  B0DB9012085EDDJVR630198
# 382217  DB90-12085E  MEMORY2(21Y)85E  B0DB9012085EDDJVR630198
# 382326  DB90-12085E  MEMORY2(21Y)85E  B0DB9012085EDDJVR630198
#
#                         QR_CODE  ...  NO892 NO893  NO894  NO895  NO896 NO897  \
# 382185  B0DB9012085EDDJVR630198  ...    NaN   NaN    NaN    NaN    NaN   NaN
# 382217  B0DB9012085EDDJVR630198  ...    NaN   NaN    NaN    NaN    NaN   NaN
# 382326  B0DB9012085EDDJVR630198  ...    NaN   NaN    NaN    NaN    NaN   NaN
#
#        NO898 NO899  NO900                          FILE_NAME
# ...

# %%
aircon1 = aircon[aircon['NO1'] == 'PASS']
df4 = aircon1[['INSP_TIME', 'HQ_CD', 'MODEL_CODE', 'MODEL_NAME', 'QR_CODE', 'NO1', 'NO2', 'NO3', 'NO4', 'NO5','NO6','NO7', 'FILE_NAME']]

# %%
df4
# Out:
#              INSP_TIME HQ_CD   MODEL_CODE   MODEL_NAME  \
# 26      20210419151811  DDJV  DB90-12086C        RODIN
# 27      20210419151646  DDJV  DB90-12086C        RODIN
# 28      20210419152408  DDJV  DB90-12086C        RODIN
# 29      20210419152514  DDJV  DB90-12086C        RODIN
# 30      20210419151632  DDJV  DB90-12086C        RODIN
# ...                ...   ...          ...          ...
# 668050  20211119151702  DDJV  DB90-12097B  �����û��97B
# 668051  20211119152420  DDJV  DB90-12097B  �����û��97B
# 668052  20211119151804  DDJV  DB90-12097B  �����û��97B
# 668053  20211119152310  DDJV  DB90-12097B  �����û��97B
# 668062  20211119154521  DDJV  DB90-12097B  �����û��97B
#
#                         QR_CODE   NO1  NO2  NO3  NO4  NO5  NO6  NO7  \
# 26      B0DB9012086CDDJVR4K0124  PASS  NaN  NaN  NaN  NaN  NaN  NaN
# 27      B0DB9012086CDDJVR4K0212  PASS  NaN  NaN  NaN  NaN  NaN  NaN
# 28      B0DB9012086CDDJVR4K0213  PASS  NaN  NaN  NaN  NaN  NaN  NaN
# ...

# %%
aircon['NO1'].unique()
# Out:
# array(['Z4556', 'PASS', 'Z7286', 'A0355', 'Z7282', 'Z7285', 'Z8642',
#        'Z7287', 'Z7945', 'Z9071', 'Z7947', 'Z7283', 'Z7841', 'Z7817',
#        'Z9073', 'Z8648', 'Z8649'], dtype=object)

# %%
aircon['NO2'].unique() #A denotes countable; C, quantity
# Out:
# array(['C', nan, 'A'], dtype=object)

# %%
aircon['NO3'].unique()  #min:50~max:100
# Out:
# array(['2.6_4.6', '2.5_4.5', '2.4_4.4', ..., '10.65_19.65', '10.40_19.40',
#        '10.33_19.33'], dtype=object)

# %%
aircon['NO4'].unique() # inspect unit
# Out:
# array([nan])

# %%
aircon['NO5'].unique() # real spot-measuring data
# Out:
# array([3.6, 3.5, 3.4, 3.7, 3.3, nan, 17.7, 17.6, 17.5, 17.4, 17.2, 17.3,
#        18.1, 18.0, 18.3, 3.8, 204.8, 18.2, 17.8, 3.2, 18.4, 18.6, 2.9,
#        18.5, 3.1, 0.0, 3.0, 2.6, 2.5, 2.8, 2.7, 1.4, 162.0, 19.1, 4.3,
#        112.0, 92.0, 127.0, 129.0, 122.0, 18.8, 18.7, 5.3, 117.0, 133.0,
#        107.0, 124.0, 19.0, 3.9, '3.4', '3.5', '3.6', '3.7', '3.2', '2.4',
#        '0.0', '3.8', '0', '2.8', '3.9', '3.1', '0.7', '2.5', '2.6', '2.7',
#        '2.9', '2.2', '2.3', '0.2', '0.1', '3.3', '2.1', '1.0', '3.0',
#        '18.5', '18.6', '18.4', '18.7', '19.1', '18.3', '18.1', '18.2',
#        '18.8', '19.0', '17.5', '17.8', '17.7', '18.0', '2293A', '4.1',
#        '19.3', '1.9', '4.3', '4.0', '19.2', '19.6', '19.4', '2320A',
#        '21.6', '22.1', '22.0', '22.2', '21.7', '21.8', '204.8', '22.3',
#        '21.5', '4.2', '21.4', '6528.0', '2184A', '22.4', '17.0', '16.4',
#        '16.8', '16.5', '17.3', '16.6', '16.3', '16.7', '17.1', '17.2',
# ...

# %%
aircon['NO6'].unique()
# Out:
# array(['OK', nan, 'NG'], dtype=object)

# %%
aircon_ok=aircon[aircon['NO6']=='OK']

# %%
aircon[aircon['NO6']=='NG']
# Out:
#          SEC_CD       INSP_TIME      PART_CD  INS_PER HQ_CD VENDOR_SEQ  \
# 715     SEC_OQC  20210428082142  DB90-12086F      NaN  DDJV       DDJV
# 821     SEC_OQC  20210428082927  DB90-12086F      NaN  DDJV       DDJV
# 900     SEC_OQC  20210414100025  DB90-12084M      NaN  DDJV       DDJV
# 904     SEC_OQC  20210414100145  DB90-12084M      NaN  DDJV       DDJV
# 907     SEC_OQC  20210414100025  DB90-12084M      NaN  DDJV       DDJV
# ...         ...             ...          ...      ...   ...        ...
# 663445  SEC_OQC  20211115101406  DB90-12152R      NaN  DK20       DK20
# 663446  SEC_OQC  20211115101428  DB90-12152R      NaN  DK20       DK20
# 663447  SEC_OQC  20211115103311  DB90-12152M      NaN  DK20       DK20
# 666834  SEC_OQC  20211122091604  DB90-12152R      NaN  DK20       DK20
# 669148  SEC_OQC  20211201163254  DB90-12152A      NaN  DK20       DK20
#
#          MODEL_CODE  MODEL_NAME              SERIAL_CODE  \
# ...

# %%
aircon[(aircon['NO6']=='OK') & (aircon['NO1']=='PASS') ]
# Out:
# Empty DataFrame
# Columns: [SEC_CD, INSP_TIME, PART_CD, INS_PER, HQ_CD, VENDOR_SEQ, MODEL_CODE, MODEL_NAME, SERIAL_CODE, QR_CODE, VEN_ECN_NO, REWORK, JIG_CD, VED_LOT_NO, INSP_NO, NO1, NO2, NO3, NO4, NO5, NO6, NO7, NO8, NO9, NO10, NO11, NO12, NO13, NO14, NO15, NO16, NO17, NO18, NO19, NO20, NO21, NO22, NO23, NO24, NO25, NO26, NO27, NO28, NO29, NO30, NO31, NO32, NO33, NO34, NO35, NO36, NO37, NO38, NO39, NO40, NO41, NO42, NO43, NO44, NO45, NO46, NO47, NO48, NO49, NO50, NO51, NO52, NO53, NO54, NO55, NO56, NO57, NO58, NO59, NO60, NO61, NO62, NO63, NO64, NO65, NO66, NO67, NO68, NO69, NO70, NO71, NO72, NO73, NO74, NO75, NO76, NO77, NO78, NO79, NO80, NO81, NO82, NO83, NO84, NO85, ...]
# Index: []
#
# [0 rows x 916 columns]

# %%
aircon[(aircon['NO6']=='OK') & (aircon['NO1']=='FAIL') ]
# Out:
# Empty DataFrame
# Columns: [SEC_CD, INSP_TIME, PART_CD, INS_PER, HQ_CD, VENDOR_SEQ, MODEL_CODE, MODEL_NAME, SERIAL_CODE, QR_CODE, VEN_ECN_NO, REWORK, JIG_CD, VED_LOT_NO, INSP_NO, NO1, NO2, NO3, NO4, NO5, NO6, NO7, NO8, NO9, NO10, NO11, NO12, NO13, NO14, NO15, NO16, NO17, NO18, NO19, NO20, NO21, NO22, NO23, NO24, NO25, NO26, NO27, NO28, NO29, NO30, NO31, NO32, NO33, NO34, NO35, NO36, NO37, NO38, NO39, NO40, NO41, NO42, NO43, NO44, NO45, NO46, NO47, NO48, NO49, NO50, NO51, NO52, NO53, NO54, NO55, NO56, NO57, NO58, NO59, NO60, NO61, NO62, NO63, NO64, NO65, NO66, NO67, NO68, NO69, NO70, NO71, NO72, NO73, NO74, NO75, NO76, NO77, NO78, NO79, NO80, NO81, NO82, NO83, NO84, NO85, ...]
# Index: []
#
# [0 rows x 916 columns]

# %%
aircon.columns[0:20]
# Out:
# Index(['SEC_CD', 'INSP_TIME', 'PART_CD', 'INS_PER', 'HQ_CD', 'VENDOR_SEQ',
#        'MODEL_CODE', 'MODEL_NAME', 'SERIAL_CODE', 'QR_CODE', 'VEN_ECN_NO',
#        'REWORK', 'JIG_CD', 'VED_LOT_NO', 'INSP_NO', 'NO1', 'NO2', 'NO3', 'NO4',
#        'NO5'],
#       dtype='object')

# %%
aircon[(aircon['NO6']=='OK') & (aircon['NO7']=='PASS') ]
# Out:
#          SEC_CD       INSP_TIME      PART_CD  INS_PER HQ_CD VENDOR_SEQ  \
# 0       SEC_OQC  20210419145444  DB90-12086C      NaN  DDJV       DDJV
# 1       SEC_OQC  20210419145446  DB90-12086C      NaN  DDJV       DDJV
# 2       SEC_OQC  20210419145448  DB90-12086C      NaN  DDJV       DDJV
# 3       SEC_OQC  20210419145517  DB90-12086C      NaN  DDJV       DDJV
# 4       SEC_OQC  20210419145521  DB90-12086C      NaN  DDJV       DDJV
# ...         ...             ...          ...      ...   ...        ...
# 669447  SEC_OQC  20211201090926  DB90-12143D      NaN  DK20       DK20
# 669448  SEC_OQC  20211201090107  DB90-12143D      NaN  DK20       DK20
# 669449  SEC_OQC  20211201091029  DB90-12143D      NaN  DK20       DK20
# 669450  SEC_OQC  20211201090949  DB90-12143D      NaN  DK20       DK20
# 669451  SEC_OQC  20211201090133  DB90-12143D      NaN  DK20       DK20
#
#          MODEL_CODE  MODEL_NAME              SERIAL_CODE  \
# ...

# %%
aircon[(aircon['NO18'] == 'OK') & (aircon['NO19']=='FAIL') ]
# Out:
#          SEC_CD       INSP_TIME      PART_CD  INS_PER HQ_CD VENDOR_SEQ  \
# 6483    SEC_OQC  20210427095013  DB90-12152G      NaN  DDJV       DDJV
# 6494    SEC_OQC  20210427094738  DB90-12152G      NaN  DDJV       DDJV
# 6496    SEC_OQC  20210427095013  DB90-12152G      NaN  DDJV       DDJV
# 13113   SEC_OQC  20210427112543  DB90-12152R      NaN  DDJV       DDJV
# 13127   SEC_OQC  20210427112543  DB90-12152R      NaN  DDJV       DDJV
# ...         ...             ...          ...      ...   ...        ...
# 667648  SEC_OQC  20211123090724  DB90-12084U      NaN  DK20       DK20
# 667649  SEC_OQC  20211123090732  DB90-12084U      NaN  DK20       DK20
# 667650  SEC_OQC  20211123090749  DB90-12084U      NaN  DK20       DK20
# 667660  SEC_OQC  20211123091535  DB90-12084U      NaN  DK20       DK20
# 667672  SEC_OQC  20211123092708  DB90-12084U      NaN  DK20       DK20
#
#          MODEL_CODE     MODEL_NAME              SERIAL_CODE  \
# ...

# %%
aircon[(aircon['NO18'] == 'NG') & (aircon['NO19']=='FAIL') ]
# Out:
#          SEC_CD       INSP_TIME      PART_CD  INS_PER HQ_CD VENDOR_SEQ  \
# 6487    SEC_OQC  20210427094740  DB90-12152G      NaN  DDJV       DDJV
# 6488    SEC_OQC  20210427095013  DB90-12152G      NaN  DDJV       DDJV
# 6489    SEC_OQC  20210427095013  DB90-12152G      NaN  DDJV       DDJV
# 6490    SEC_OQC  20210427095013  DB90-12152G      NaN  DDJV       DDJV
# 6491    SEC_OQC  20210427095013  DB90-12152G      NaN  DDJV       DDJV
# ...         ...             ...          ...      ...   ...        ...
# 198382  SEC_OQC  20210518183005  DB90-12152P      NaN  DK20       DK20
# 198419  SEC_OQC  20210518190007  DB90-12152G      NaN  DK20       DK20
# 198424  SEC_OQC  20210518190007  DB90-12152G      NaN  DK20       DK20
# 198440  SEC_OQC  20210518185806  DB90-12152P      NaN  DK20       DK20
# 199104  SEC_OQC  20210518185253  DB90-12152P      NaN  DK20       DK20
#
#          MODEL_CODE  MODEL_NAME              SERIAL_CODE  \
# ...

# %%
aircon['NO7'].unique()
# Out:
# array(['PASS', nan, 'Z7287', 'Z7285', 'Z8642', 'FAIL', 'Z7282', 'Z7947',
#        'Z7817', 'Z7286', 'A0355', 'Z7841', 'Z9071', 'Z9073', 'Z7283',
#        'Z7945', 'Z8649', 'Z8648'], dtype=object)

# %%
aircon['NO8'].unique()
# Out:
# array([nan, 'C', 'A'], dtype=object)

# %%
history.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299826 entries, 0 to 299825
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   WORK_YMD       299826 non-null  int64
#  1   ASSY_DT        299826 non-null  int64
#  2   MODEL_CODE     299826 non-null  object
#  3   PRODC_MAGT_NO  299826 non-null  object
#  4   VEND_CODE      299826 non-null  object
#  5   MATR_CODE      299826 non-null  object
#  6   ASSY_NO        299826 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 16.0+ MB
